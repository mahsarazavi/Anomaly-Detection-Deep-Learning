# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import csv
import collections
import time
from sklearn.metrics import classification_report
import tensorflow as tf

# %% [markdown]
# # Open dataset files

# %%
Dataset = collections.namedtuple('Dataset', ['data', 'target'])
label_numbers = {'normal':0,'dos':1,'probe':2,'u2r':3,'r2l':4}

TRAINING_FILE_20P = '/content/drive/My Drive/20\ Percent\ Training\ Set.csv'
TRAINING_FILE_SMALL = '/content/drive/My Drive/Small\ Training\ Set.csv'
TRAINING_FILE_FULL = '/content/drive/My Drive/KDDTrain+.txt'
TEST_FILE = '/content/drive/My Drive/KDDTest+.txt'

# %% [markdown]
# # Read csv files in numpy arrays

# %%
def simple_csv_to_array(csv_file):
    """Make an array from a csv file
    """

    to_return = []
    packets = csv.reader(open(csv_file), delimiter=',',dialect=csv.excel_tab)
    for packet in packets:
        tmp = []
        for feature_index in range(0,len(packet)):
            tmp.append(packet[feature_index])
        to_return.append(tmp)
    return to_return

# %% [markdown]
# # Feature Extraction

# %%
# convert labels to numbers
def binarize_labels(raw_labels,label_lookups):

    labels = []
    # Figure out which group 
    for label in raw_labels:
        if not label == 'normal':
            label = label_lookups[label]
        label_number = label_numbers[label]
        # Make all non-normal packets anomalies
        # Just for now :)
        if label_number != 0: label_number = 1
        labels.append(np.int(label_number))
        if label_number != 1 and label_number != 0:
            print("Error")
    return np.array(labels)

# %%
# convert fetures to numbers
def binarize_features(raw_features,conversion_lookups):

    features = []

    for packet in raw_features:
        tmp = []
        for feature_index in range(0,len(packet)):
            if feature_index in conversion_lookups.keys():
                binarize = [np.float32(0.0)]*len(conversion_lookups[feature_index])
                # length of binarize is how many possible qualitative features
                label = packet[feature_index] # ex. 'tcp'
                if(conversion_lookups[feature_index].get(label)):
                    binarize[conversion_lookups[feature_index][label]] = np.float32(1.0)
                    #        --------    map    -------------
                    #										  --key--
                    #        --------- index -------------------------
                tmp.extend(binarize)
            else:
                tmp.append(np.float32(packet[feature_index]))

        features.append(np.array(tmp))

    features = np.array(features)
    return features

# %%
def map_for_labels(labels):
    """ given a list of values, return a map of label->val
    i.e. {'tcp':0,'ftp':1,etc}
    """
    the_map = {}
    for label in labels:
    	if not label in the_map:
        	the_map[label] = len(the_map.keys())
    return the_map

# %%
def feature_names(): 
    """An array of the KDD features, represented as dictionaries"""

    return [
        # c = continuous feature
        # d = discrete feature
        # basic features (0-8)
        {'name':'duration','type':'c'},
        {'name':'protocol_type','type':'d'},
        {'name':'service','type':'d'},
        {'name':'flag','type':'d'},
        {'name':'src_bytes','type':'c'},
        {'name':'dst_bytes','type':'c'},
        {'name':'land','type':'d'},
        {'name':'wrong_fragment','type':'c'},
        {'name':'urgent','type':'c'},
        
        {'name':'hot','type':'c'},
        {'name':'num_failed_logins','type':'c'},
        {'name':'logged_in','type':'d'},
        {'name':'num_compromised','type':'c'},
        {'name':'root_shell','type':'d'},
        {'name':'su_attempted','type':'d'},
        {'name':'num_root','type':'c'},
        {'name':'num_file_creations','type':'c'},
        {'name':'num_shells','type':'c'},
        {'name':'num_access_files','type':'c'},
        {'name':'num_outbound_cmds','type':'c'},
        {'name':'is_hot_login','type':'d'},
        {'name':'is_guest_login','type':'d'},
        
        {'name':'count','type':'d'},
        {'name':'srv_count','type':'d'},
        {'name':'serror_rate','type':'c'},
        {'name':'srv_serror_rate','type':'c'},
        {'name':'rerror_rate','type':'c'},
        {'name':'srv_rerror_rate','type':'c'},
        {'name':'same_srv_rate','type':'c'},
        {'name':'diff_srv_rate','type':'c'},
        {'name':'srv_diff_host_rate','type':'c'},
        # host based traffic features (31-40)
        {'name':'dst_host_count','type':'d'},
        {'name':'dst_host_srv_count','type':'d'},
        {'name':'dst_host_same_srv_rate','type':'c'},
        {'name':'dst_host_diff_srv_rate','type':'c'},
        {'name':'dst_host_same_src_port_rate','type':'c'},
        {'name':'dst_host_srv_diff_host_rate','type':'c'},
        {'name':'dst_host_serror_rate','type':'c'},
        {'name':'dst_host_srv_serror_rate','type':'c'},
        {'name':'dst_host_rerror_rate','type':'c'},
        {'name':'dst_host_rerror_rate','type':'c'},
        {'name':'dst_host_srv_rerror_rate','type':'c'}
    ]

# %%
def get_label_groups():
    """ The label groups for types of attacks"""

    return  {	    # denial of service attacks
					'back':'dos',
					'land':'dos',
					'neptune':'dos',
					'pod':'dos',
					'smurf':'dos',
					'teardrop':'dos',
					'apache2':'dos',
					'udpstorm':'dos',
					'processtable':'dos',
					'worm':'dos',
                    'mailbomb':'dos',

					# probe attacks
					'satan':'probe',
					'ipsweep':'probe',
					'nmap':'probe',
					'portsweep':'probe',
					'mscan':'probe',
					'saint':'probe',

					# root to local (r2l) attacks
					'guess_passwd':'r2l',
					'ftp_write':'r2l',
					'imap':'r2l',
					'phf':'r2l',
					'multihop':'r2l',
					'warezmaster':'r2l',
					'warezclient':'r2l' ,
					'spy':'r2l',
					'xlock':'r2l',
					'xsnoop':'r2l',
					'snmpguess':'r2l',
					'snmpgetattack':'r2l',
					'httptunnel':'r2l',
					'sendmail':'r2l',
					'named':'r2l',

					# user to root (u2r) attacks
					'buffer_overflow':'u2r',
					'loadmodule':'u2r',
					'rootkit':'u2r',
                    'perl':'u2r',
                    'sqlattack':'u2r',
					'xterm':'u2r',
					'ps':'u2r'
			}

# %% [markdown]
# # Deep Neural Network Implementation

# %%
def run_dnn_with_units_steps(training_set,test_set,units_array,num_steps):
  
    # as per tensorflow's recommendation / sample code
    x_train, x_test, y_train, y_test = training_set.data, test_set.data, \
              training_set.target, test_set.target


    #Build a DNN!
    start = time.clock()
    feature_columns = [tf.contrib.layers.real_valued_column("", dimension=1)]
    
    classifier = tf.contrib.learn.DNNClassifier(feature_columns=feature_columns, hidden_units=units_array)
    classifier.fit(x=x_train, y=y_train, steps=num_steps)
    test_pred = classifier.predict(x_test)
    
    stop = time.clock()


    print('---------------------------------------------')
    print('DNN with hidden units: ' + str(units_array))
    print('Number of steps: ' + str(num_steps))
    print('Seconds elapsed: {}'.format(stop - start))
    print(classification_report(list(y_test),list(test_pred)))
    print('---------------------------------------------')

# %%
# Grab the raw data at face value
training_file = np.array(simple_csv_to_array(TRAINING_FILE_FULL))
testing_file = np.array(simple_csv_to_array(TEST_FILE))

# Determine the number of columns
columns = len(training_file[0])
# Delete the last column
training_file = np.delete(training_file,columns-1,1)
testing_file = np.delete(testing_file,columns-1,1)

# Separate labels and features
training_labels = training_file[:,columns-2]
testing_labels = testing_file[:,columns-2]
training_features = np.delete(training_file,columns-2,1)
testing_features = np.delete(testing_file,columns-2,1)

# Determine which features need lookups
# that is, which features are qualitative
# ex. 'tcp'
feature_lookups = {}
for i in range(0,len(training_file[0])):
    try:
        np.float32(training_file[0][i])
    except ValueError as e:
        feature_lookups[i] = map_for_labels(training_file[:,i])

 
label_lookups = get_label_groups()

training_features = binarize_features(training_file,feature_lookups)
test_features = binarize_features(testing_file,feature_lookups)
training_labels = binarize_labels(training_labels,label_lookups)
test_labels = binarize_labels(testing_labels,label_lookups)
print("NUMBER OF FEATURES AFTER BINARIZATION:")
print(len(training_features[0]))
# Out:
# NUMBER OF FEATURES AFTER BINARIZATION:
# 145

# %%
# Group features and datasets
the_training_set = Dataset(training_features,training_labels)
the_test_set = Dataset(test_features,test_labels)

num_features = len(training_features[0])
unit_trials = []
unit_trials.append([num_features]) #baseline
unit_trials.append([num_features,2*num_features])
unit_trials.append([num_features,2*num_features,num_features])

step_trials = []
step_trials.append(100)
step_trials.append(200)
step_trials.append(300)

# %%
the_training_set# Run the dnn with every possible configuration
for trial in unit_trials:
    for num_steps in step_trials:
        run_dnn_with_units_steps(the_training_set,the_test_set,trial,num_steps)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpq2e1gyek
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe8e7ffac88>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpq2e1gyek', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpq2e1gyek/model.ckpt.
# INFO:tensorflow:loss = 367.88504, step = 0
# INFO:tensorflow:Saving checkpoints for 100 into /tmp/tmpq2e1gyek/model.ckpt.
# INFO:tensorflow:Loss for final step: 406.57355.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpq2e1gyek/model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ---------------------------------------------
# DNN with hidden units: [145]
# Number of steps: 100
# Seconds elapsed: 25.469899999999996
#               precision    recall  f1-score   support
#
#            0       0.60      0.86      0.71      9711
#            1       0.85      0.57      0.68     12833
#
#     accuracy                           0.70     22544
#    macro avg       0.72      0.72      0.70     22544
# weighted avg       0.74      0.70      0.69     22544
#
# ---------------------------------------------
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpu56h8q68
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe8e4315780>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpu56h8q68', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpu56h8q68/model.ckpt.
# INFO:tensorflow:loss = 951.9542, step = 0
# INFO:tensorflow:global_step/sec: 4.36851
# INFO:tensorflow:loss = 801.1311, step = 100 (22.893 sec)
# INFO:tensorflow:Saving checkpoints for 200 into /tmp/tmpu56h8q68/model.ckpt.
# INFO:tensorflow:Loss for final step: 178.33638.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu56h8q68/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ---------------------------------------------
# DNN with hidden units: [145]
# Number of steps: 200
# Seconds elapsed: 47.167145000000005
#               precision    recall  f1-score   support
#
#            0       0.62      0.96      0.75      9711
#            1       0.95      0.55      0.69     12833
#
#     accuracy                           0.72     22544
#    macro avg       0.78      0.75      0.72     22544
# weighted avg       0.80      0.72      0.72     22544
#
# ---------------------------------------------
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpq4bat38a
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe8e8424b00>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpq4bat38a', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpq4bat38a/model.ckpt.
# INFO:tensorflow:loss = 659.949, step = 0
# INFO:tensorflow:global_step/sec: 4.40182
# INFO:tensorflow:loss = 160.04958, step = 100 (22.721 sec)
# INFO:tensorflow:global_step/sec: 4.43428
# INFO:tensorflow:loss = 334.95407, step = 200 (22.551 sec)
# INFO:tensorflow:Saving checkpoints for 300 into /tmp/tmpq4bat38a/model.ckpt.
# INFO:tensorflow:Loss for final step: 136.7116.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpq4bat38a/model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ---------------------------------------------
# DNN with hidden units: [145]
# Number of steps: 300
# Seconds elapsed: 68.51074300000002
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.77      9711
#            1       0.95      0.60      0.74     12833
#
#     accuracy                           0.76     22544
#    macro avg       0.80      0.78      0.75     22544
# weighted avg       0.82      0.76      0.75     22544
#
# ---------------------------------------------
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpmppvtvcx
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe8e4509da0>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpmppvtvcx', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpmppvtvcx/model.ckpt.
# INFO:tensorflow:loss = 380.0729, step = 0
# INFO:tensorflow:Saving checkpoints for 100 into /tmp/tmpmppvtvcx/model.ckpt.
# INFO:tensorflow:Loss for final step: 56.201702.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpmppvtvcx/model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ---------------------------------------------
# DNN with hidden units: [145, 290]
# Number of steps: 100
# Seconds elapsed: 30.863241000000016
#               precision    recall  f1-score   support
#
#            0       0.59      0.89      0.71      9711
#            1       0.87      0.53      0.66     12833
#
#     accuracy                           0.69     22544
#    macro avg       0.73      0.71      0.69     22544
# weighted avg       0.75      0.69      0.68     22544
#
# ---------------------------------------------
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp9bs034mq
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe8e826ba20>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmp9bs034mq', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp9bs034mq/model.ckpt.
# INFO:tensorflow:loss = 3683.9792, step = 0
# INFO:tensorflow:global_step/sec: 3.48229
# INFO:tensorflow:loss = 23.448313, step = 100 (28.722 sec)
# INFO:tensorflow:Saving checkpoints for 200 into /tmp/tmp9bs034mq/model.ckpt.
# INFO:tensorflow:Loss for final step: 35.88088.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9bs034mq/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ---------------------------------------------
# DNN with hidden units: [145, 290]
# Number of steps: 200
# Seconds elapsed: 58.40025399999996
#               precision    recall  f1-score   support
#
#            0       0.65      0.89      0.76      9711
#            1       0.89      0.64      0.75     12833
#
#     accuracy                           0.75     22544
#    macro avg       0.77      0.77      0.75     22544
# weighted avg       0.79      0.75      0.75     22544
#
# ---------------------------------------------
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpx5lg5pub
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe8e831e470>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpx5lg5pub', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpx5lg5pub/model.ckpt.
# INFO:tensorflow:loss = 125.225555, step = 0
# INFO:tensorflow:global_step/sec: 3.49397
# INFO:tensorflow:loss = 74.39896, step = 100 (28.623 sec)
# INFO:tensorflow:global_step/sec: 3.51844
# INFO:tensorflow:loss = 60.315735, step = 200 (28.427 sec)
# INFO:tensorflow:Saving checkpoints for 300 into /tmp/tmpx5lg5pub/model.ckpt.
# INFO:tensorflow:Loss for final step: 78.783424.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpx5lg5pub/model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ---------------------------------------------
# DNN with hidden units: [145, 290]
# Number of steps: 300
# Seconds elapsed: 84.91809599999999
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77      9711
#            1       0.94      0.60      0.74     12833
#
#     accuracy                           0.75     22544
#    macro avg       0.79      0.78      0.75     22544
# weighted avg       0.82      0.75      0.75     22544
#
# ---------------------------------------------
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpxi21camc
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe8e852e9e8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpxi21camc', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpxi21camc/model.ckpt.
# INFO:tensorflow:loss = 531.8703, step = 0
# INFO:tensorflow:Saving checkpoints for 100 into /tmp/tmpxi21camc/model.ckpt.
# INFO:tensorflow:Loss for final step: 38.11324.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxi21camc/model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ---------------------------------------------
# DNN with hidden units: [145, 290, 145]
# Number of steps: 100
# Seconds elapsed: 33.44253599999996
#               precision    recall  f1-score   support
#
#            0       0.59      0.72      0.65      9711
#            1       0.75      0.62      0.68     12833
#
#     accuracy                           0.66     22544
#    macro avg       0.67      0.67      0.66     22544
# weighted avg       0.68      0.66      0.66     22544
#
# ---------------------------------------------
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp3sa5dzc_
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe8e824dcf8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmp3sa5dzc_', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp3sa5dzc_/model.ckpt.
# INFO:tensorflow:loss = 246.58812, step = 0
# INFO:tensorflow:global_step/sec: 3.35529
# INFO:tensorflow:loss = 8.931285, step = 100 (29.806 sec)
# INFO:tensorflow:Saving checkpoints for 200 into /tmp/tmp3sa5dzc_/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.5048775.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp3sa5dzc_/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ---------------------------------------------
# DNN with hidden units: [145, 290, 145]
# Number of steps: 200
# Seconds elapsed: 62.07623699999999
#               precision    recall  f1-score   support
#
#            0       0.63      0.94      0.76      9711
#            1       0.93      0.59      0.72     12833
#
#     accuracy                           0.74     22544
#    macro avg       0.78      0.76      0.74     22544
# weighted avg       0.80      0.74      0.73     22544
#
# ---------------------------------------------
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp7k45jdul
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe8e92fcb70>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmp7k45jdul', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp7k45jdul/model.ckpt.
# INFO:tensorflow:loss = 341.43927, step = 0
# INFO:tensorflow:global_step/sec: 3.34259
# INFO:tensorflow:loss = 0.7639379, step = 100 (29.925 sec)
# INFO:tensorflow:global_step/sec: 3.38352
# INFO:tensorflow:loss = 1.5290188, step = 200 (29.550 sec)
# INFO:tensorflow:Saving checkpoints for 300 into /tmp/tmp7k45jdul/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.105352.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp7k45jdul/model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ---------------------------------------------
# DNN with hidden units: [145, 290, 145]
# Number of steps: 300
# Seconds elapsed: 90.63336700000002
#               precision    recall  f1-score   support
#
#            0       0.63      0.90      0.74      9711
#            1       0.89      0.61      0.72     12833
#
#     accuracy                           0.73     22544
#    macro avg       0.76      0.75      0.73     22544
# weighted avg       0.78      0.73      0.73     22544
#
# ---------------------------------------------
